# %% [markdown]
# # Semana 1- Clase 1
# #### Temas Selectos Proceso Químicos: Análisis de Datos con Python

# %% [markdown]
# - Trimestre 26-I
# - Clave: 2122075
# - Grupo: CH03
# - Dra. Abigail Marin López(amarin@xanum.uam.mx)
# - Otros asuntos: marinlopabi@gmail.com

# %% [markdown]
# - Horario: Lunes, Miércoles y Viernes (Sala-F) de 14:30 a 16:00.
# - Tareas: temas.datosiq@gmail.com

# %% [markdown]
# # **Introducción al análisis de datos con Pyhton**

# %% [markdown]
# *¿Qué es un lenguaje de programación?*
#
# Es un con junto de reglas y símbolos para dar instrucciones a la computadora.
#
# Este lenguaje usa reglas (léxicas, sintácticas y semánticas) que deben cumplirse para que la maquina lo interprete correctamente.
#
# La computadora ejecuta estas instrucciones para realizar tareas específicas, como crear aplicaciones, controlar el funcionamiento de dispositivos o gestionar datos.

# %% [markdown]
# ![1680508406460.png](data:image/png;base64,...)

# %% [markdown]
# **¿Qué es Python?**
#
# Es un lenguaje de programación de alto nivel, de código abierto y muy popular.
#
#
# *Python fue creado a finales de los años ochenta por Guido van Rossum en Stichting Mathematisch Centrum (CWI), en los Países Bajos.*
#
#
# Amplio uso en:
# - Aplicaciones web
# - Desarrollo de software
# - Ciencia de datos Machine Learning
#
#
# Beneficios:
#
# - Sintaxis sencilla y legible, parecida al inglés.
# - Permite programar con menos líneas de código que otros lenguajes.
# - Incluye una gran biblioteca estándar con código reutilizable.
# - Tiene una comunidad global activa que brinda soporte.
# - Es multiplataforma: funciona en Windows, macOS, Linux.

# %% [markdown]
# # **Análisis de Datos**

# %% [markdown]
# El análisis de datos es el proceso de inspeccionar, limpiar, transformar y modelar datos con el objetivo de descubrir información útil, llegar a conclusiones y respaldar la toma de decisiones.

# %% [markdown]
# Responder preguntas como:

# %% [markdown]
# ![descarga.jpeg](data:image/jpeg;base64,...)
# ![desca.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Generar gráficos, resúmenes estadísticos y patrones descriptivos.

# %% [markdown]
# Jupyter Notebook
#
#
# *   Aplicación web de código abierto para crear y compartir código y documentos.
# * Entorno interactivo que permite experimentar y mostrar resultados.
# * Originalmente pensado para Julia, Python y R.

# %% [markdown]
# Google Colab
#
#
# Colab es un servicio de Cuaderno de Jupyter que no requiere configuración para usar y proporciona acceso gratuito a los recursos informáticos.
#
#
# - Funciona en Mac, Windows o Linux (solo necesitas un navegador como Chrome o Safari).
#
# - No requiere instalación de Python.
#
# - Permite colaborar con otras personas (como Google Docs).
# - Viene con muchas librerías científicas preinstaladas (NumPy, pandas, matplotlib, TensorFlow, etc.).

# %% [markdown]
# ![Captura de pantalla 2026-01-19 a la(s) 2.32.06 a.m..png](data:image/png;base64,...)

# %% [markdown]
# **GitHub**
#
# Es una plataforma en línea para guardar, compartir y colaborar en proyectos de código.

# %% [markdown]
# ![64e79ca5aff2fb7295bfddf9_github-que-es.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - COrreo electrónico
# - Nombre de usuario
# - Contraseña
#
# https://github.com

# %% [markdown]
# # Tipos de datos

# %% [markdown]
# Los tipos primitivos o tipos de datos en python son las estructuras de datos más elementales del lenguaje de programación. Son los componentes básicos para tratar todo tipo de datos o variables.
#
# Python tiene cuatro tipos primitivos:
#
# - Los tipos de variables enteros en Python **int** se utilizan para representar números enteros.
#
# - Los tipos de datos flotantes en Python **float** se utilizan para representar números con decimales.
#
# - Los tipos de datos **string** son un arreglo de caracteres que forman cadenas para formar una oración.
#
# - Los tipos  booleanos en python **bool** son tipos de datos binarios, es decir que pueden tomar los valores: Verdadero (True) y Falso (False). Son útiles para expresiones con condicionales y de comparaciones.

# %% [markdown]
# **Ejemplos de tipos de datos en Python**

# %%
a = 3 #Dato tipo entero
b = 4.5
c = 'alumno' #Datos tipo cadena siempre deben de ir dentro de comillas
d = False

# %% [markdown]
# **Listas**

# %% [markdown]
# Una lista es una secuencia de valores. Es un tipo de contenedor usado para almacenar un número indefinido de datos arbitrarios del mismo tipo o de tipos distintos.

# %% [markdown]
# Las listas en Python tienen las siguientes propiedades:
#
# * Son ordenadas: cada elemento dentro de la lista está indexado y mantiene el orden definido.
#
# * Permiten elementos duplicados: las listas pueden tener elementos con el mismo valor.
#
# * Las listas pueden anidar, es decir, contener una lista dentro de la otra.
#
# * Son mutables: podemos editar, eliminar o agregar elementos en una lista existente (.append(), .remove(),lista1[x] = y)

# %% [markdown]
# *Sintaxis:*
#
# nombre = [elemento 1, elemento 2, ...,elemento n]
#
# **Ejercicio**: Crear 3 listas.
#
# - Datos tipo int
# - tipo cadena
# - combinando datos **int**, **float**, **cadena**.

# %%
lista_1 = [3,4,5]
lista2 = ['uno', 'dos', 'tres'] #Tipo cadena
lista3 = ['uno', 2, 3.14, [10, 20, 30]]

# %%
print(lista_1)
lista_1
# Out:
# [3, 4, 5]
# [3, 4, 5]

# %% [markdown]
# Para llamar listas:

# %%
lista_1 #Llama la lista 1
# Out:
# [3, 4, 5]

# %%
lista3
# Out:
# ['uno', 2, 3.14, [10, 20, 30]]

# %% [markdown]
# Para llamar un dato de una lista:

# %%
lista3[3] #Llama al valor de la posición 3 de la lista3
# Out:
# [10, 20, 30]

# %%
lista_1[-1]
# Out:
# 5

# %% [markdown]
# | Índice | Elemento        |
# | ------ | --------------- |
# | 0      | Primer elemento |
# | 1      | Segundo         |
# | -1     | Último          |
# | -2     | Penúltimo       |

# %% [markdown]
# Para cambiar el valor de una lista:

# %%
lista_1[1]=15 #se cambia el valor de la posición 1 al valor igual a 15

# %%
lista_1  #Al llamar nuevamente la lista se observa el cambio del valor 4 por 15
# Out:
# [3, 15, 5]

# %% [markdown]
# Para añadir datos usamos append.
# - **append** sirve para agregar un elemento al final de una lista.
#
# - Añade un solo elemento
#
# - Lo coloca al final de la lista
#
# - Modifica la lista original (no crea una nueva)
#
# *Sintaxis:*
#
# nombredelalista.append(elemento)

# %%
lista_1.append(10) #nombre de la lista.append(valor nuevo)

# %%
lista_1
# Out:
# [3, 15, 5, 10]

# %% [markdown]
# Para eliminar usamos remove

# %%
lista_1.remove(10) #nombre de la lista.remove(valor a eliminar)

# %%
lista_1
# Out:
# [3, 15, 5]

# %% [markdown]
# ### Cadenas de Texto

# %%
nombre = "Abi"
saludo = "Hola " + nombre
print(saludo)
# Out:
# Hola Abi

# %% [markdown]
# Las cadenas de texto de Python son inmutables; no se pueden modificar:

# %%
a ='esto es una cadena'
a
# Out:
# 'esto es una cadena'

# %%
a[8]
# Out:
# 'u'

# %% [markdown]
# Si necesitamos modificar una cadena de texto, tenemos que utilizar una función que cree una nueva cadena, como la función **.replace()** para cadenas de texto:

# %%
b = a.replace('cadena', 'cadena grande')

# %%
b
# Out:
# 'esto es una cadena grande'

# %% [markdown]
# Muchos objetos de Python se pueden transformar en una cadena de texto utilizando la función **str()**

# %%
g=7.8
g
# Out:
# 7.8

# %% [markdown]
# Para convertir de número a texto

# %%
h=str(g)
h
# Out:
# '7.8'

# %% [markdown]
# Sumar dos cadenas las concatena y produce una nueva:

# %%
a = 'primera mitad'
b = ' y segunda mitad'

# %%
a+b
# Out:
# 'primera mitad y segunda mitad'
